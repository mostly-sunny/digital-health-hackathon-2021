# %% [markdown]
# <a href="https://colab.research.google.com/github/mostly-sunny/digital-health-hackathon/blob/main/analyse_result.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 학습된 모델의 치료효능률 결과 분석
#
# ## Requirements
#
# ### Library
# - pandas
#
# ### Input file
# - 모델 결과 csv 파일

# %% [markdown]
# - DataFrame 사용을 위한 pandas import

# %%
import pandas as pd

# %%
dataset = pd.read_csv('/content/c_index_2_2100_4000.csv')

# %% [markdown]
# - rank.csv의 형식 확인

# %%
dataset.head()
# Out:
#    Unnamed: 0   c index     brier  ...      G298      G299      G300
# 0           0  0.704840  0.054987  ...  0.656982  0.681648  0.646780
# 1           1  0.710425  0.053601  ...  0.546923  0.538813  0.561451
# 2           2  0.615479  0.056180  ...  0.627832  0.612214  0.662576
# 3           3  0.710535  0.053707  ...  0.543534  0.561280  0.576936
# 4           4  0.702431  0.054505  ...  0.666102  0.651175  0.690734
#
# [5 rows x 307 columns]

# %% [markdown]
# # Brier Score가 낮은 순으로 정렬
# -

# %%
dataset.sort_values(by=['c index'])
# Out:
#      Unnamed: 0   c index     brier  ...      G298      G299      G300
# 45           45  0.571237  0.057803  ...  0.946291  0.958696  0.959768
# 69           69  0.589909  0.057973  ...  0.876996  0.889836  0.890504
# 6             6  0.590648  0.058542  ...  0.779798  0.773827  0.766904
# 65           65  0.593605  0.058001  ...  0.965421  0.983686  0.985540
# 226         226  0.595192  0.058521  ...  0.691852  0.686116  0.696869
# ..          ...       ...       ...  ...       ...       ...       ...
# 131         131  0.724717  0.054145  ...  0.585915  0.578536  0.601284
# 201         201  0.724990  0.053169  ...  0.500955  0.506885  0.576671
# 140         140  0.725209  0.054402  ...  0.590919  0.592151  0.630289
# 233         233  0.725401  0.053060  ...  0.512289  0.484510  0.566280
# 221         221  0.726058  0.053357  ...  0.435997  0.465839  0.481986
#
# [240 rows x 307 columns]

# %% [markdown]
# # 기준 Brier Score보다 작은 행 삭제

# %%
list_for_del=[]

# %%
standard = 0.7

# %%
for i in range(len(dataset)):
  if dataset['c index'].values[i] < standard:
      list_for_del.append(i)

# %%
dataset_modified = dataset.drop(list_for_del)

# %%
dataset_modified
# Out:
#      Unnamed: 0   c index     brier  ...      G298      G299      G300
# 0             0  0.704840  0.054987  ...  0.656982  0.681648  0.646780
# 1             1  0.710425  0.053601  ...  0.546923  0.538813  0.561451
# 3             3  0.710535  0.053707  ...  0.543534  0.561280  0.576936
# 4             4  0.702431  0.054505  ...  0.666102  0.651175  0.690734
# 5             5  0.701281  0.054387  ...  0.623514  0.610509  0.670948
# ..          ...       ...       ...  ...       ...       ...       ...
# 232         232  0.716503  0.054433  ...  0.602819  0.563657  0.616464
# 233         233  0.725401  0.053060  ...  0.512289  0.484510  0.566280
# 235         235  0.707332  0.053589  ...  0.471595  0.473590  0.516629
# 236         236  0.711876  0.054901  ...  0.658523  0.655302  0.654004
# 237         237  0.709823  0.053754  ...  0.448765  0.471270  0.496017
#
# [138 rows x 307 columns]

# %% [markdown]
# # 등수 평균

# %%
rank_average = []
for i in range(300):
  rank_average.append([dataset_modified['G' + str(i+1)].values.mean(), 'G' + str(i+1)])
rank_average.sort()

# %%
rank_average
# Out:
# [[0.5571969067272933, 'G280'],
#  [0.557296357077101, 'G196'],
#  [0.5648099898860075, 'G82'],
#  [0.566333520239678, 'G74'],
#  [0.5679219617791798, 'G152'],
#  [0.5687267596738926, 'G180'],
#  [0.5696351182633552, 'G284'],
#  [0.5699783993372018, 'G111'],
#  [0.570837235753087, 'G197'],
#  [0.5708663718423982, 'G137'],
#  [0.5709956990203996, 'G205'],
#  [0.5711152309524841, 'G291'],
#  [0.5733074541541113, 'G88'],
#  [0.5736043522323387, 'G230'],
#  [0.5736823932848115, 'G39'],
#  [0.5741195382847302, 'G169'],
#  [0.5749557895072992, 'G242'],
#  [0.575098234674205, 'G73'],
#  [0.5755678430415582, 'G285'],
#  [0.5772363197976265, 'G19'],
#  [0.57821842185829, 'G136'],
#  [0.5786763762218364, 'G156'],
#  [0.5787481490684592, 'G174'],
#  [0.5801737111979637, 'G202'],
#  [0.5802183768887451, 'G297'],
#  [0.5802271137202996, 'G35'],
#  [0.5802930841843287, 'G263'],
#  [0.5812723984320959, 'G143'],
#  [0.5814895921427271, 'G89'],
#  [0.5820094606150752, 'G10'],
# ...

# %% [markdown]
# # TOP 10 빈도수 확인
